# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
x=[1,2,3,4,5,6,7]
y=[50,56,67,46,39,78,89]
plt.plot(x,y)

# %%
plt.plot(x,y,'b+--')

# %%
# Same effect as 'b+' format string
plt.plot(x,y,color='blue',marker='+',linestyle='')

# %%
#Marker size
plt.plot(x,y,color='blue',marker='+',linestyle='',markersize=20)

# %%
# alpha property to control transparency of line chart
plt.plot(x,y,'g<',alpha=0.5) # alpha can be specified on a scale 0 to 1

# %%
plt.xlabel('days')
plt.ylabel('temperature')
plt.title ('lineplot')
plt.plot(x,y,color='green',linewidth=5,linestyle='dotted')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14932/199662292.py in <module>
# ----> 1 plt.xlabel('days')
#       2 plt.ylabel('temperature')
#       3 plt.title ('lineplot')
#       4 plt.plot(x,y,color='green',linewidth=5,linestyle='dotted')
#
# TypeError: 'str' object is not callable

# %%
plt.plot(x,y,'rD')

# %%
days=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,48,46,40,42,41]

# %%
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")

# %%
# set axes labels and chart title
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')

plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14932/4047296321.py in <module>
#       1 # set axes labels and chart title
# ----> 2 plt.xlabel('Day')
#       3 plt.ylabel('Temperature')
#       4 plt.title('Weather')
#       5
#
# TypeError: 'str' object is not callable

# %%
# Show legend
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")

plt.legend(loc='best')

# %%
# Legend at different location with shadow enabled and fontsize set to large
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")

plt.legend(loc='upper right',shadow=True,fontsize='large')

# %%
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")

plt.legend(loc='upper right',shadow=True,fontsize='small')
plt.grid()

# %%
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,89,27]

# %%
xpos = np.arange(len(company)) # changing company to x-position becoze it doesnt handle string values convert it to numbers
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.bar(xpos,revenue, label="Revenue")

plt.xticks(xpos,company)
plt.ylabel("Revenue(Bln)")
plt.title("US Technology Stocks")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14932/2061995027.py in <module>
#       2
#       3 plt.xticks(xpos,company)
# ----> 4 plt.ylabel("Revenue(Bln)")
#       5 plt.title("US Technology Stocks")
#       6 plt.legend()
#
# TypeError: 'str' object is not callable

# %%
profit=[40,2,34,12]

# %%
plt.bar(xpos,revenue, label="Revenue")
plt.bar(xpos,profit,label="Profit")
plt.legend()

# %%
plt.bar(xpos-0.2,revenue, label="Revenue")
plt.bar(xpos+0.2,profit,label="Profit")
plt.legend()

# %%
plt.bar(xpos-0.2,revenue, width=0.4, label="Revenue")
plt.bar(xpos+0.2,profit, width=0.4,label="Profit")

plt.xticks(xpos,company)
plt.ylabel("Revenue(Bln)")
plt.title('US Technology Stocks')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14932/3963089308.py in <module>
#       3
#       4 plt.xticks(xpos,company)
# ----> 5 plt.ylabel("Revenue(Bln)")
#       6 plt.title('US Technology Stocks')
#       7 plt.legend()
#
# TypeError: 'str' object is not callable

# %%
plt.barh(xpos,revenue, label="Revenue")

plt.yticks(xpos,company)
plt.ylabel("Revenue(Bln)")
plt.title('US Technolog Stocks')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14932/2681389351.py in <module>
#       2
#       3 plt.yticks(xpos,company)
# ----> 4 plt.ylabel("Revenue(Bln)")
#       5 plt.title('US Technolog Stocks')
#       6 plt.legend()
#
# TypeError: 'str' object is not callable

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# <h1 align="center", style="color:green">Matplotlib Tutorial: Histogram</h1>

# %% [markdown]
# **We have a sample data of blood sugar level of different patients, we will try to plot number of patients by blood range and try to figure out how many patients are normal, pre-diabetic and diabetic**

# %%
blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
plt.hist(blood_sugar, rwidth=0.8) # by default number of bins is set to 10
# Out:
# (array([3., 3., 1., 0., 1., 1., 0., 2., 0., 2.]),
#  array([ 77. ,  84.3,  91.6,  98.9, 106.2, 113.5, 120.8, 128.1, 135.4,
#         142.7, 150. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(blood_sugar,rwidth=0.5,bins=4)
# Out:
# (array([7., 1., 2., 3.]),
#  array([ 77.  ,  95.25, 113.5 , 131.75, 150.  ]),
#  <BarContainer object of 4 artists>)

# %% [markdown]
# **Histogram showing normal, pre-diabetic and diabetic patients distribution**
# - 80-100: Normal
# - 100-125: Pre-diabetic
# - 80-100: Diabetic

# %%
plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")

plt.hist(blood_sugar, bins=[80,100,125,150], rwidth=0.95, color="g")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14932/45128996.py in <module>
# ----> 1 plt.xlabel("Sugar Level")
#       2 plt.ylabel("Number Of Patients")
#       3 plt.title("Blood Sugar Chart")
#       4
#       5 plt.hist(blood_sugar, bins=[80,100,125,150], rwidth=0.95, color="g")
#
# TypeError: 'str' object is not callable

# %%
plt.hist(blood_sugar, bins=[80,100,125,150], rwidth=0.95, color="g")
# Out:
# (array([6., 2., 4.]),
#  array([ 80, 100, 125, 150]),
#  <BarContainer object of 3 artists>)

# %% [markdown]
# ## Mutiple data samples in a histogram

# %%
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")

plt.hist([blood_sugar_men,blood_sugar_women], bins=[80,100,125,150], rwidth=0.95, color=['green','orange'],label=['men','women'])
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14932/1767085686.py in <module>
# ----> 1 plt.xlabel("Sugar Level")
#       2 plt.ylabel("Number Of Patients")
#       3 plt.title("Blood Sugar Chart")
#       4
#       5 blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
#
# TypeError: 'str' object is not callable

# %%
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]
plt.hist([blood_sugar_men,blood_sugar_women], bins=[80,100,125,150], rwidth=0.95, color=['green','orange'],label=['men','women'])
plt.legend()

# %%
#histtype=step
plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")

plt.hist(blood_sugar,bins=[80,100,125,150],rwidth=0.95,histtype='step')

# %%
plt.hist(blood_sugar,bins=[80,100,125,150],rwidth=0.95,histtype='step')
# Out:
# (array([6., 2., 4.]),
#  array([ 80, 100, 125, 150]),
#  [<matplotlib.patches.Polygon at 0x242f8ed2130>])

# %%
plt.hist(blood_sugar, bins=[80,100,125,150], rwidth=0.95, orientation='horizontal')
# Out:
# (array([6., 2., 4.]),
#  array([ 80, 100, 125, 150]),
#  <BarContainer object of 3 artists>)

# %% [markdown]
# <h1 align="center", style="color:green">Matplotlib Tutorial: Pie Charts</h1>

# %%
exp_vals = [1400,600,300,410,250]
exp_labels = ["Home Rent","Food","Phone/Internet Bill","Car ","Other Utilities"]
plt.pie(exp_vals,labels=exp_labels)
plt.show()

# %%
#Draw pie chart as perfect circle
plt.pie(exp_vals,labels=exp_labels, shadow=True)
plt.axis("equal")
plt.show()

# %%
#Show percentages for every pie. Specify radius to increase chart size
plt.axis("equal") # formate string with %f%%
plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%1.1f%%',radius=1.5)
plt.show()

# %%
#Explode
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%1.1f%%',radius=1.5,explode=[0,0,0,0.1,0.2])
plt.show()

# %%
#counterclock and angle properties
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%1.1f%%',radius=1.5,explode=[0,0,0,0.1,0.2],counterclock=True, startangle=45)
plt.show()

# %% [markdown]
# ### Saving chart to a file using savefig

# %%
exp_vals = [1400,600,300,410,250]
exp_labels = ["Home Rent","Food","Phone/Internet Bill","Car ","Other Utilities"]

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels,radius=2, autopct='%0.1f%%', explode=[0,0.1,0.1,0,0])
plt.savefig("piechart.jpg", bbox_inches="tight", pad_inches=1, transparent=True)

# %% [markdown]
# **You can also save in pdf format and to a different location on your computer by specifying absolute path**

# %%
plt.pie(exp_vals,labels=exp_labels,radius=2, autopct='%0.1f%%', explode=[0,0.1,0.1,0,0])
plt.savefig("d:/codebasics/piechart.pdf", bbox_inches="tight", pad_inches=10, transparent=True
# Out:
#   File "C:\Users\satin\AppData\Local\Temp/ipykernel_14932/3092717736.py", line 2
#     plt.savefig("d:/codebasics/piechart.pdf", bbox_inches="tight", pad_inches=10, transparent=True
#                                                                                                   ^
# SyntaxError: unexpected EOF while parsing

# %%
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,89,27]
plt.bar(company,revenue, label="Revenue")

#plt.xticks(xpos,company)
#plt.ylabel("Revenue(Bln)")
#plt.title("US Technology Stocks")
#plt.legend()
# Out:
# <BarContainer object of 4 artists>
